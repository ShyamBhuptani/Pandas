# %%
import math
import numpy as np
np.sin(np.deg2rad(30))
# Out:
# 0.49999999999999994

# %%
#for theta in range(86,88,0.2):
for theta in np.arange(86,88,0.01):
    LHS = 84.5813 * np.cos(np.deg2rad(theta))
    sinThe = np.sin(np.deg2rad(theta))
    cosThe = np.cos(np.deg2rad(theta))
    Fun1 = sinThe*sinThe - 0.1837
    if Fun1 >= 0:
        mainFun1 = (math.sqrt(Fun1)/cosThe)
    Fun2 = sinThe*sinThe - 0.0816
    if Fun2 >= 0:
        mainFun2 = (math.sqrt(Fun2)/cosThe)
    mainX = math.atan(np.rad2deg(mainFun1)) + math.atan(np.rad2deg(mainFun2))
    #if ()
    print("LHS : ",LHS,"val of theta ", theta ,"and value of RHS" , mainX)
# Out:
# LHS :  5.90009323269398 val of theta  86.0 and value of RHS 3.1389673003272187
# LHS :  5.885366881229146 val of theta  86.01 and value of RHS 3.138973890100827
# LHS :  5.870640350485784 val of theta  86.02000000000001 and value of RHS 3.1389804796755643
# LHS :  5.855913640912473 val of theta  86.03000000000002 and value of RHS 3.138987069051938
# LHS :  5.841186752957851 val of theta  86.04000000000002 and value of RHS 3.138993658230455
# LHS :  5.826459687070487 val of theta  86.05000000000003 and value of RHS 3.139000247211622
# LHS :  5.811732443699029 val of theta  86.06000000000003 and value of RHS 3.1390068359959464
# LHS :  5.797005023292059 val of theta  86.07000000000004 and value of RHS 3.1390134245839354
# LHS :  5.782277426298239 val of theta  86.08000000000004 and value of RHS 3.1390200129760952
# LHS :  5.767549653166156 val of theta  86.09000000000005 and value of RHS 3.139026601172932
# ...

# %%
\usepackage{amsmath}
\begin{document}

\[
M=
  \begin{bmatrix}
    1 & 2 & 3 & 4 & 5 \\
    3 & 4 & 5 & 6 & 7
  \end{bmatrix}
\]
# Out:
#   File "<ipython-input-5-a79877d97ec0>", line 1
#     \usepackage{amsmath}
#                         ^
# SyntaxError: unexpected character after line continuation character
