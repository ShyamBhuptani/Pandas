# %% [markdown]
# ## Data frame

# %%
import pandas as pd

# %%
nba = pd.read_csv("nba.csv")  # they convert int to float if 1 single value is NaN

# %%
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.index  # index object
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values  # rows become list and will be part of array
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.shape # dimension
# Out:
# (458, 9)

# %%
nba.dtypes # data type column wise
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.columns #column names
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.axes # details of index + column
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.info()  # info of data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.get_dtype_counts() # data type wise count
# Out:
# float64    4
# object     5
# dtype: int64

# %%
rev = pd.read_csv("revenue.csv", index_col="Date")
rev
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/16        985          122    499
# 1/2/16        738          788    534
# 1/3/16         14           20    933
# 1/4/16        730          904    885
# 1/5/16        114           71    253
# 1/6/16        936          502    497
# 1/7/16        123          996    115
# 1/8/16        935          492    886
# 1/9/16        846          954    823
# 1/10/16        54          285    216

# %%
s = pd.Series([1,2,7])
s.sum()
# Out:
# 10

# %%
rev.sum() # sum by column which is basic
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %% [markdown]
# ## Sum by Column # Basic

# %%
rev.sum(axis= 0)  # sum Normally
rev.sum(axis='index')  # Sum normally via column
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %% [markdown]
# ## Sum by Rows

# %%
rev.sum(axis=1) # Sum row wise
rev.sum(axis='columns') # sum row wise
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
nba.Number #extract column where column name doesnt have spaces
nba.Salary
Output = None
# Out:
# 0       7730337.0
# 1       6796117.0
# 2             NaN
# 3       1148640.0
# 4       5000000.0
# 5      12000000.0
# 6       1170960.0
# 7       2165160.0
# 8       1824360.0
# 9       3431040.0
# 10      2569260.0
# 11      6912869.0
# 12      3425510.0
# 13      1749840.0
# 14      2616975.0
# 15      3425510.0
# 16       845059.0
# 17      1500000.0
# 18      1335480.0
# 19      6300000.0
# 20      1599840.0
# 21       134215.0
# 22      1500000.0
# 23     19689000.0
# 24      1140240.0
# 25       947276.0
# 26       981348.0
# 27       947276.0
# 28       947276.0
# 29     11235955.0
#           ...
# 428     8042895.0
# 429      625093.0
# 430      947276.0
# 431     6980802.0
# 432     2894059.0
# 433     6000000.0
# 434     5016000.0
# 435     3075880.0
# 436     4236287.0
# 437     2525160.0
# 438      525093.0
# 439     1415520.0
# 440     2854940.0
# 441     2637720.0
# 442     4775000.0
# 443     2658240.0
# 444     9463484.0
# 445     3777720.0
# 446    12000000.0
# ...

# %%
nba["Number"] # best when we have space in name
nba["Number"]
type(nba[["Number","Salary"]]) # data type
# Out:
# 0       0.0
# 1      99.0
# 2      30.0
# 3      28.0
# 4       8.0
# 5      90.0
# 6      55.0
# 7      41.0
# 8      12.0
# 9      36.0
# 10      7.0
# 11      4.0
# 12     11.0
# 13     13.0
# 14     44.0
# 15     44.0
# 16     22.0
# 17     21.0
# 18     24.0
# 19      2.0
# 20     10.0
# 21      6.0
# 22      0.0
# 23     11.0
# 24      1.0
# 25     33.0
# 26     41.0
# 27     14.0
# 28     15.0
# 29     30.0
#        ...
# 428     8.0
# 429     5.0
# 430    23.0
# 431    17.0
# 432     4.0
# 433     9.0
# 434    35.0
# 435    11.0
# 436     0.0
# 437     3.0
# 438    44.0
# 439    24.0
# 440     2.0
# 441    21.0
# 442    33.0
# 443     3.0
# 444    10.0
# 445    11.0
# 446    15.0
# 447    27.0
# 448    20.0
# 449     5.0
# 450     2.0
# 451    23.0
# 452    41.0
# 453     8.0
# 454    25.0
# 455    21.0
# 456    24.0
# 457     NaN
# Name: Number, Length: 458, dtype: float64

# %%
nba[["Team","Height","Name"]] # for multiple column in order
Output = None

# %%
select = ["Team","Height","Name"]
nba[select].head(2) # through list
# Out:
#              Team Height           Name
# 0  Boston Celtics    6-2  Avery Bradley
# 1  Boston Celtics    6-6    Jae Crowder

# %%
nba["Sport"] = "Basketball" # will add new column
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba.insert(3,"Key",1) # Insert column position wise

# %%
nba.head(3)
# Out:
#             Name            Team  Number  Key Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0    1       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0    1       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0    1       SG  27.0    6-5   205.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball

# %%
nba["Age"].add(5) # add anything to column
nba["Age"].head(3)+5  # same as above but smarter way
nba["Salary"].sub(500000)
nba["Salary"] - 500000
nba["Weight"]*0.45
nba["Weight in KG"]= nba["Weight"].mul(0.45) # mul and add new column

# %%
nba["Salary"].div(1000)
nba["Salary"]//1000
Output = None

# %%
nba = pd.read_csv("nba.csv")
nba["Team"].value_counts()
nba["Position"].value_counts()  # counts value column vise
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
nba["Weight"].value_counts().tail()
nba["Salary"].value_counts()
Output = None

# %%
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.dropna() # removes all row which has at least One NAN value
nba.dropna(how="all",inplace=True) # only removes where all values are NAN

# %%
nba.dropna(axis=1) # removes columns where at least one null value
nba.dropna(axis="columns") # same as above
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba.dropna()
